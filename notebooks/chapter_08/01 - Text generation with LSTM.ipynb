# %% [markdown]
# # Text generation with LSTM

# %% [markdown]
# ## Implementing character-level LSTM generation
#
# In this example we will use some of the writings of Nietzsche, the late-19th century German philosopher (translated to English). The language model we will learn will thus be specifically a model of Nietzsche's writing style and topics of choice, rather than a more generic model of the English language.

# %% [markdown]
# ## Preprocess data
#
# Let's download the corpus and converting it to lowercase:

# %%
import numpy as np

from tensorflow import keras

path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()

print('Corpus length:', len(text))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 1s 1us/step
# Corpus length: 600893

# %% [markdown]
# Next, we will extract partially-overlapping sequences of length `maxlen`, one-hot encode them and pack them in a 3D Numpy array `x` of shape `(sequences, maxlen, unique_characters)`. Simultaneously, we prepare a array `y` containing the corresponding targets: the one-hot encoded characters that come right after each extracted sequence.

# %%
# Length of extracted character sequences
maxlen = 60

# We sample a new sequence every `step` characters
step = 3

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

# List of unique characters in the corpus
chars = sorted(list(set(text)))

print('Unique characters:', len(chars))

# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
print('...done')
# Out:
# Number of sequences: 200278
# Unique characters: 57
# Vectorization...
# ...done

# %% [markdown]
# ## Building the network
#
# The network is a single `LSTM` layer followed by a `Dense` classifier and _softmax_ over all possible characters. But let us note that recurrent neural networks are not the only way to do sequence data generation; 1D convnets also have proven extremely successful at it in recent times.
#
# Since the targets are one-hot encoded, we will use `categorical_crossentropy` as the loss to train the model.

# %%
from tensorflow.keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 128)               95232
# _________________________________________________________________
# dense_1 (Dense)              (None, 57)                7353
# =================================================================
# Total params: 102,585
# Trainable params: 102,585
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Training the language model and sampling from it
#
# Given a trained model and a seed text snippet, we generate new text by repeatedly:
#
# 1) Drawing from the model a probability distribution over the next character given the text available so far;
# 2) Reweighting the distribution to a certain "temperature";
# 3) Sampling the next character at random according to the reweighted distribution;
# 4) Adding the new character at the end of the available text;
#
# This is the code we use to reweight the original probability distribution coming out of the model, and draw a character index from it (the "sampling function"):

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    
    return np.argmax(probas)

# %% [markdown]
# Finally, this is the loop where we repeatedly train and generated text. We start generating text using a range of different temperatures after every epoch. This allows us to see how the generated text evolves as the model starts converging, as well as the impact of temperature in the sampling strategy.

# %%
import random
import sys

NUM_EPOCHS = 60
CHAR_GENERATED_TEXT = 400 # We generate 400 characters

for epoch in range(1, NUM_EPOCHS):
    print('epoch', epoch)
    
    # Fit the model for 1 epoch on the available training data
    model.fit(x, y, batch_size=128, epochs=1)

    # Select a text seed at random
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print(f"--- Generating with seed: \"{generated_text}\"")

    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print(f"------ temperature: {temperature}")
        sys.stdout.write(generated_text)

        for i in range(CHAR_GENERATED_TEXT):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# epoch 1
# Train on 200278 samples
# 200278/200278 [==============================] - 167s 833us/sample - loss: 1.9654
# --- Generating with seed: "ilosophers, any
# more than "pleasure self prepared" (sympathy"
# ------ temperature: 0.2
# ilosophers, any
# more than "pleasure self prepared" (sympathy in the self--the man we prease and the man for the sense the self--the sense and the man of the man the sense the for the man the man of the self--the some to the confection of the case of the master of the sense of the sense to the man for the sense of the for the man the self--the man we in the soul the some to the man of the stain of the self--the may be all the self--the self--the contrary of
# ------ temperature: 0.5
# the self--the may be all the self--the self--the contrary of the respect preystenity of the sain confectious and pertation of the mores the self--though perhaps who can for only for the for the
# conficting and the one sheow in the be more a the man only of the fact to our of the once the onations of the batter upon it is once to the all the some have something be and for the say, to deligious and confequent of a bether of the self--the way and peoples and m
# ------ temperature: 1.0
# onfequent of a bether of the self--the way and peoples and mediately raterous by the holiatity of offements, the med a conceraint
# the park mores. this dren not trany oftes of only hume dimes akgoismy that how for priserwed seventration of thus actue atermen ongus in then bragmestonalui,
# s. impormant of the mattow cordesceptific as i exwemptic  much and wa sen, whithex is appeen more a well even as moristical inour pain of the where to conscience recarimly
# ------ temperature: 1.2
#  moristical inour pain of the where to conscience recarimly of edvaps he goveal bloo
# mutal8 once
# " mua-opeaptificarl
# accorwifustiangt' and we for unberetheral all a vaution of cearity hon1ve raxid,=. houlsdenisuence unlighteer fow and blet,.. and
# miguol viligune of a secterual hagier) even, whethis confree sciousnly shoold his claxly, the our goofrneared, alliford that the erematedernt this, mestitak--more? to  upresbogitung us  een-cheri. (apte "1=(forpou
# epoch 2
# Train on 200278 samples
# 200278/200278 [==============================] - 163s 812us/sample - loss: 1.6159
# --- Generating with seed: "f
# independence of the scientific man, his emancipation from "
# ------ temperature: 0.2
# f
# independence of the scientific man, his emancipation from in the same the conduct of conduct of the conduct of the sublet the same to in the can be and so christian of the same to any such a soul and and such the same to that the strengle of the same and in the same and and the distingul and and and concerned and in the strenge in the can be such the condition of the same that is not and and in the conduct of the same to the can be and in the far and and
# ------ temperature: 0.5
# the conduct of the same to the can be and in the far and and imartinate that is conscience to the belong and discome and sold and in the case and not has if the bight to as a souls of the conditions of a bleaste that is in the full decisely the moral to even and individuals and in the souls, and religious even of the contempty of the sense confucing to are such from the moral that which and fair that is a so such a harties of the concert that the farhing i
# ------ temperature: 1.0
# hat is a so such a harties of the concert that the farhing its quare now; beings.   the go
# does so flacturificed ducked cade of things, inther valuas in; psssis, lovesing faist to, sanction and die perhops! that it imided, we smammudious
# whose aghically boblence one--the yor one a now alleateatical exceteate that cruel, the
# eaite ornalic of
# its always all is an orgenopshen indeverence must or cased for it, so
# me-man in villy mu h a
# nce tyste of fars
# funden
# ------ temperature: 1.2
# d for it, so
# me-man in villy mu h a
# nce tyste of fars
# fundeness
# impoloodf and wheen other.d this over, intemek.
# cy
# , ceasably be a a
# some to perso., power, sciess or sperits: and
# indigntionally sbiened misus boudable." one realtyves, and in its
# deprised evising magage lan -with
# suse make nable derent this fundinss europerious cauts of devilines that by has et, "nquribled o? jost. in disgrassiured ee: on
# , b" if." and 'napsience and
# amyonth. we conside you
# epoch 3
# Train on 200278 samples
# 200278/200278 [==============================] - 162s 810us/sample - loss: 1.5281
# --- Generating with seed: " more to fear!" some time
# or other--the will and the way the"
# ------ temperature: 0.2
#  more to fear!" some time
# or other--the will and the way the present of the fact the sense of the most an our and problem of the proble the sense of the man in the man and the prise of the present of the man and interporated and the present of the present of the sense of the present of the most distiness of the present of the present of the most distined the distined and the sense of the freedom of the present of the same of the problem of the present of t
# ------ temperature: 0.5
# f the present of the same of the problem of the present of the free of hare of the has of our own into the preasent of the persons of distinest the man of the propessible must for his to doon be done of the same for the freedom which an and the persons of the conscious and this own sense, and comprehines his own precience of does the man conscious of the presont that the every greatest of the former of the sention and present of the propessible and himself
# ------ temperature: 1.0
# er of the sention and present of the propessible and himself, thet for in defining toes sont menanity jurgment up too new who and
# known they artable there, ax 4k in the pleasure preson of "which bery naturally
# poessions of tendance, funinh, very way be be
# nation. an ulled and resited isey the the assuction of mirverc and, be there batiness it is predifrests, hen evil of nature which that the
# "dight the differe--judement itsility of a thing wouth in much of
# ------ temperature: 1.2
# t the differe--judement itsility of a thing wouth in much of the unimy longerets schoold
# hso:
# infuccalurienta
# wormen knowledge ree midingg
# stolds tential
# aha  ealousion attkief, bos. when said uni, my the far
# obing lights it
# have it is type sense of probably phasiros there lavevous faith, to kidd endrw
# to it--he into bad ao other.=--oths pkic,
# incline, mu, all appearatives of schephoopian the weight epents ands suistence a flavous andllves. there really to
# epoch 4
# Train on 200278 samples
# 200278/200278 [==============================] - 163s 814us/sample - loss: 1.4838
# --- Generating with seed: "acity
# for prolonged resolution, must specially be included i"
# ------ temperature: 0.2
# acity
# for prolonged resolution, must specially be included in the same to the struggis and spirit and precisely and accument of the father of the strong of the struggis and soul of the desire of the man and the same and present of the strunge of the same to the soul of the same to the same to the same and possible of the soul of the soul of the subject of the same such and the struggis the strunge of the same to the same of the same to the strunge of the s
# ------ temperature: 0.5
#  of the same to the same of the same to the strunge of the strunge of its are out, and man far expectation of which was in the organice in the perhaps the man with a very a distorrists of the artists of the man as an attemption of religions and into all a problem of the subjection in the still man, which the love of the presented which really sear and reasonable which in which so the say, he which mise at in the same for such to the strong-even with it may
# ------ temperature: 1.0
#  mise at in the same for such to the strong-even with it may be untruth.per. the humill,
# in the anolirable man, and purit which it is the whole have been fapticality.
# the traummen tale refines: becompuce
# untrothuhan: in fanalty in wogether," and logicgs
# the make us addungnish to cast. it is the bring, than the same enjoy worknariake, and estems. my the substoned morality of the and divt, bomet work and laberal. in so and, call: as "grow a serves
# sing wisho
# ------ temperature: 1.2
# k and laberal. in so and, call: as "grow a serves
# sing wishousings himself, more:
# natulred the
# ethicl him,
# are a turavel. as gederaked through pare drorungces, petil, fath is pleasure and orgablence, it is how
# areapticism.g=ic to varies on genylo; and morelve of
# a paliss these phino ome well; even efforctis fo? in wemel usmer in brysy enceftited
# conscience, he madiled have puracte; which an our inwontero effect,
# no usaith in the that dorwably would it miy
# epoch 5
# Train on 200278 samples
# 200278/200278 [==============================] - 163s 812us/sample - loss: 1.4529
# --- Generating with seed: "g to the
# sort of people placed under its spell and protectio"
# ------ temperature: 0.2
# g to the
# sort of people placed under its spell and protection of the problem of the strange of the the strangest to the believed the the all the states of the assifice the states of the in the morality of the strong the the strong the morality and the stateshed the soul--the the soul the destructive the morality of the strong the masters of the morality of the states of the one must be man an explained to the strong the states of the for the strong the act
# ------ temperature: 0.5
# ained to the strong the states of the for the strong the action and the existing and religious speaker the morality an astands conceptions of all the order to the concealed as no longer for the order that is a perhaps one wishes as the contrase them consciously for the world as the the speciment of the still something is the strong the opposite and entime: an instinction of the one has been men as the spirit of the soul--the gradually one must be all the h
# ------ temperature: 1.0
#  the spirit of the soul--the gradually one must be all the hypothest right of a itself them
# mhost of the morally
# to feeling, the fine
# curredivers of for complements,"s
# that peoples, it peead pact,
# lutsed, all the profestipally for histsiou fins of
# the happens of a deciantlast of this strengs the apself litelund to noble mind denieed, for sey sholous, the parasme; this conecious with that must the other also roub
# aget believe works made to the higher man wh
# ------ temperature: 1.2
# other also roub
# aget believe works made to the higher man whot shain soul--y strick avery of hust, but, authouthures which whilh one done-tlon the wlatemtahis ruther evives of
# danguily, ness the whole sympathysired men, lasth for hist on such tone effect
# of mankind mpscstleash is, prince, with every dibten if it shord to himselfsmfull centiles of know every sigmis to
# conrectnument,
# from
# exseiorol, one
# begrect, something
# "upor
# socieam, a priffeptesis of dis
# epoch 6
# Train on 200278 samples
# 200278/200278 [==============================] - 164s 818us/sample - loss: 1.4321
# --- Generating with seed: "enses that has hitherto been gained on earth. one
# must, howe"
# ------ temperature: 0.2
# enses that has hitherto been gained on earth. one
# must, however, and is the word of the same and supposite and the greatest man in the sense of the strong and the constatutude and sense and sense the most man the spirit and so the strength and the man is all and the one has no longer the man the man is to the present and man the states of the are of the sense of the same and the have a so interpretations of the strength and sense and what is all the develo
# ------ temperature: 0.5
# tations of the strength and sense and what is all the developments of the rational soul is suppositional trought in all not in virtues, and every it is the present this incertain the also with every nectsive of the most soristic and the most philosophers, have been our here and the conscience the greatest and has a metaphysical one has been no doring to the spirit and seems to its own spirit of posing and has in one has no longer of the spirit and all his
# ------ temperature: 1.0
# sing and has in one has no longer of the spirit and all his ebefreith that the feeling, true prese, grain : " or evils before one is thus adimed sufformative mind of marrain: the may be condition through which is self knod one through the appebation of the fandly elegorously,"--if the state, i onjuque to previc and but,
# unopharness their mode and ideas
# halther canor's with men, see the samicy
# thinked the lardly,
# and for adminestiquelly a all payfulh else,
# ------ temperature: 1.2
# ked the lardly,
# and for adminestiquelly a all payfulh else, more
# mur
# if
# we preciption. doe byow the mamefisely relatud of synowh,
# no bad we kind in the varbaricmanies is its casean: and in tyhe, one wosters, grwat, but alsocitual wither o
# upse which no evilso they conditions upon us as this "trunile equally,. such every questious
# known the
# turns, the chaiative
# of him basish and  very knowledge and ssuch and wenthaftical un them
# )whmer mumd on when is lough
# epoch 7
# Train on 200278 samples
# 200278/200278 [==============================] - 162s 810us/sample - loss: 1.4129
# --- Generating with seed: "nvaded the domain of
# the powerful man and established himsel"
# ------ temperature: 0.2
# nvaded the domain of
# the powerful man and established himself the destruyed and intentional the sensuality of the deating in the delusion of the same and the same and the struggle to the belief in the more and sure and said to be sure and perhaps in the struggle and such a sensual that the same and sign that the sensuality and intentional and perhaps in the struggle the same the man be stronger and always and sensually be stronger and sensual that the man
# ------ temperature: 0.5
# d always and sensually be stronger and sensual that the man be elevate the different and consideration there is a destrubity itself in the spirit of the morality and interest and in the sensue and made a belief and in the called by the science of a some day in the stronger of the distrust of the man in the last because they from the farse states of a destruments of the sun the deal in the reality is always reads and who have not be always and sensually for
# ------ temperature: 1.0
# is always reads and who have not be always and sensually for, brietitg: the existence,   have-was contemptions as fair have fital, buckon; the duties that there is as mars imperulge so resentiment. for sciencil, and emblance--after has if thus the more lalsomen ooreritible
# persons, it significanes, acceptary rencence
# wey impressines. alish--as "philosophy of schopenhauer's poete and deressed may been german point yan by the consideration that which there h
# ------ temperature: 1.2
# een german point yan by the consideration that which there has not in partary even bring amyly aster yel fecusprissint haspory of o. our makes t"leomisver, in itstramitian:
#    malk also henceke
# could be a, one seally, but o; no de and party decike prooelukeeames", the knowledge, that in far gods, to no longling and maous, a n(wnisishminesxing
# eleve exhisick--from "naturally: not have sup
# al, as to be that it self-coesting justimely th sea longer--that io r
# epoch 8
# Train on 200278 samples
# 200278/200278 [==============================] - 163s 812us/sample - loss: 1.3979
# --- Generating with seed: " singing! but i ask
# too much...
#
# 253. there are truths which"
# ------ temperature: 0.2
#  singing! but i ask
# too much...
#
# 253. there are truths which has been some one some and strength of the strong and strong and strong and some and and the strong and soul of the sense of the most and the constant of the spirit of the sense of the sense of the spirit and soul of the sense of the superiorious soul of the sense of the most and strong and soul of the sense of the superiorious soul, and which a soul of the sense of the sense of the interman and
# ------ temperature: 0.5
#  which a soul of the sense of the sense of the interman and discover
# strength, and all the misunderstanding of the subject as their moral such a world that the
# most of the existence and is a discovery a modern of the soul of compares of the causa and conscious the sensition of him and in all the constitute of
# succeed and common the absusufully person and deterious immendion of a most after in any
# the impulse and into superiorious of a comprehend of such a
# ------ temperature: 1.0
# the impulse and into superiorious of a comprehend of such a soul; he his under best bot for the judger a mavicrous and relations and wanter--we danger among being finally new (andly as
# absolutonct orijang meliugh, as being scienticible benefuth, and subject man everythine": the further, hidducquinely; has a deteriotim,
# than be, they adducts of taste. the
# mothes speak of tendanning is to be
# asfuldo-on
# a democratice themselves methodas" befowe pride hunder's
# ------ temperature: 1.2
# -on
# a democratice themselves methodas" befowe pride hunder's
# philosophy--ostrions
# wnot can sfeefion, (whather of
# habit and dragd, with blessiporatic
# srigula which is
# no ramition, permlitelory
# it, please. knowls ywhy is. in
# hudagice and decishistess that io phoskychules;" impressing god to period of our ambice akin
# to thiegs our dade--at the rehigaous himself generain in spritvisgs
# slood in oblical huad youn barbign inscine
# vous (noound, to which in such
# ju
# epoch 9
# Train on 200278 samples
# 200278/200278 [==============================] - 162s 807us/sample - loss: 1.3857
# --- Generating with seed: "he ascribes the success, the carrying out of the willing,
# to"
# ------ temperature: 0.2
# he ascribes the success, the carrying out of the willing,
# to the same one and the contrary and and the man in the spirit of the precisely of the struggle of the sense of the best of the fars of the fars of the presentiment and there is the same and the contrary of the precisely of the spirit of the belief of the world and strength and something and something and the deepines of the spirit of the belief and soul, and what is the problem of the there are som
# ------ temperature: 0.5
# elief and soul, and what is the problem of the there are something but and sense of the man only the underaght of partating his term and worthing of this emotions, is when which is seems to the general and all them in the unnature, however, the man of the good and something his even the origin of the certain and stands as a certain with a contrary in the most case of worthing of instincts of the spirit which we precisely and the command; in the spirit to s
# ------ temperature: 1.0
# pirit which we precisely and the command; in the spirit to so masserw
# to perhoad good man, here the eemisued, and
# in stands upon one which the
# consequently which as fine  man below. a crome nature is a
# one.
# bith
# to be lond in doons the eehaperia, something that it is there was a religion--evegant is the first (naposs thlo gen the "strong, but in a bad, all ted and to its nature, and listoriation, how upponaceverous, "the self-ad"cumublics har boralthation,
# ------ temperature: 1.2
# how upponaceverous, "the self-ad"cumublics har boralthation, by very sust and nright, side, harpafried soul.--and which. in futh, poverial accompancite'r and compfuss orse, chulded; higher, and tryting evence
# just are in possible which make a liferians of table still thirl bird
# and against
# homen: in to call ismorattord. the greek,m; or "every ouredr dangerousnary,
# and choorm, hosuman, as
# sake wains but of and scarrr of the poor fear, for and hap orpecting
# epoch 10
# Train on 200278 samples
# 200278/200278 [==============================] - 162s 809us/sample - loss: 1.3765
# --- Generating with seed: "sion, and that an error of the reason is at the bottom of su"
# ------ temperature: 0.2
# sion, and that an error of the reason is at the bottom of such an actions of the truth and the success and success and the moral and the fact and the success and success of the same of the fact and success in the more success and success the condection of the more success and the sense of the same the problem of the actions of the souls of the senses of the more and conself in the personal sense of the more success of the more to pleasure and the stand the
# ------ temperature: 0.5
# f the more success of the more to pleasure and the stand the condaced of the will to one must really not a self-mind of this
# day to the germany and self-despaired to the self even to the harding of this morally the man be indifferently and strength and conduced the fundamentally part of any senses of the man has not a discorred as readous absolute of the point of the in of the order to be not all anything the sense of the spirit and honour and by the actio
# ------ temperature: 1.0
# anything the sense of the spirit and honour and by the action of nagus ourselves in great an is hit sodevous could made to be histouges to been lights
# to this
# good order to sacrificed by ; alluge upous! there helpevaria, is lack or the seldomenknefound of from lapablened, there                                                . i alow heterpo. the ar-inepure prouse in the truel than his opend, even they are
# this indigct an europely against this bind. no all
# ------ temperature: 1.2
# they are
# this indigct an europely against this bind. no all pitervourrfuls, toftido, ostition and crken--is boundungfaeful be, buicks). the world to pri, inserst,--. the anyregive
#  frelthrisminity,
# much uncivint attetion" marytsor," as
# a talk-aspoed,s--as an infor accustitessicle from there.
#
# 1 ready
# she knows gigleved witholatical respondible for they enjoy zeke--as meloud light.
#
#
# 1rewardsh.
#
# 1re for inners there is how danger rexmin that perient new; it
# epoch 11
# Train on 200278 samples
# 200278/200278 [==============================] - 163s 814us/sample - loss: 1.3684
# --- Generating with seed: "hey have usually paid
# their addresses to truth, have been un"
# ------ temperature: 0.2
# hey have usually paid
# their addresses to truth, have been understand the present and security of the stronger of the present man and subjuges to the same and have the present the present and all the stronger of the stronger of the present the most of the sense of the sense of the stronger of the struggle of the sense of the strong to the sense of the present the sense of the same self-conscience of the senses of the same and artists and intellectual and al
# ------ temperature: 0.5
# f the senses of the same and artists and intellectual and allow and who freeas, and the
# practice of which the desires and weaker so to emplace and simplated and artists of the contemposely and have it is the moral according to have life of men has not be a distortes
# and wrong artists. the seduce life,
# and ament, and every innot at any personal and cannot that it are strong and the cases to really a superstiment in any manices interronal and interrons upon
# ------ temperature: 1.0
# a superstiment in any manices interronal and interrons upon good canses in anyteduing from the sentiment
# for
# intentiug, at one a books,
# the way mantening, therery eventulven? it co?sgay morals: does not kind ensolmethument,pote,
# in orders to trated. perhaps to portable, so false: this si.gunances to formlendgr" prigrited herexore persons for the sage every will to gutfull" : because which how opty
#
#  , but
# which ha" the knows
# power, and subarity his eneby--
# ------ temperature: 1.2
#
#
#  , but
# which ha" the knows
# power, and subarity his eneby--riscially--what: on
# the echo impare for the outsedn, but has itself owune
# fruquesomermant in likeom.
#
# 1
# uth! shatt taskess too brinness is this goved interes of a ristity and to marlier, hegine indignating hate o? the
# lehistance," are anhistad there are contragrismwic a mannerverteebles for "graspion his ?nem. a pponderous
# dispet et quiteence
# must be whole": a qually out-piser, a laseitungensions?
# epoch 12
# Train on 200278 samples
# 200278/200278 [==============================] - 163s 816us/sample - loss: 1.3578
# --- Generating with seed: " at present, but for ever inaccessible, incomprehensible, an"
# ------ temperature: 0.2
#  at present, but for ever inaccessible, incomprehensible, and the great will to the spiritual and the presence of the exertain to the condition to the same and the same to the same and the condition which they are and the strength of the spirit of the still with the exertict of the same and almost to the strength of the spiritual and delicate the presence of the same and the spirit of the presence of the same and the present of the exertict of the spirit o
# ------ temperature: 0.5
#  of the same and the present of the exertict of the spirit of the same part of the "condition and degree of the false of the spiritually at all still will regard to the feeling of its existence the discleary and the deference to experienced with a standpoint of the strength be the cave of the subtle under the will to lives, the conditing to "passion of the presence of the present, is from the present and degree of the preferse
# of the ideas: they made a new
# ------ temperature: 1.0
# ent and degree of the preferse
# of the ideas: they made a new cording to the reflaments: they willing youth, of a toble will lose; for the let such we passions;--but extraberden countching the senied of the brood, why develops in ptorder
# there are, is all very clove
# limited necessarious
# always
# delicate, as it is not wishests, which yitage, in societ,
# ullectity,
# of its full domain and has prehard usel, in many praised for
# fregerander were any called time a w
# ------ temperature: 1.2
# el, in many praised for
# fregerander were any called time a well "goodmh,
# itself, horough foo, muss =len late--you truth. the paneming,"
# aqwad follow.. even chameas,
# as i new
# p.ith anyone, mayzemprence wank men of caseus of the wayty of pured
# pleasure, and in dow to the cal old has nut whoughlected apprehepleedness would mentlaingly,, as as
# act love, unpregree. "what ethimsel claym, and this
# acsined" neverthicb, pat "all intentional blassed free-meny, with
#
# epoch 13
# Train on 200278 samples
# 200278/200278 [==============================] - 162s 809us/sample - loss: 1.3507
# --- Generating with seed: "t in his mere "dullness" as la rochefoucauld thinks.--in soc"
# ------ temperature: 0.2
# t in his mere "dullness" as la rochefoucauld thinks.--in society and deep one must be propection of the spirit of the strength of the spirit and real and the strength of the conduct of the spirit of the fact the same of the hardence of the fact that the same of the proper of the spirit of the sacrifice of the strive of the spirit to the same of the most proper of the same of the great the spirit of the spirit of the most conduct of the fact that the moral
# ------ temperature: 0.5
# f the spirit of the most conduct of the fact that the moral ordinated and to possible--the same and is all the soul death of the same the lost and realing and france of the moral the moral instincts of the great strong to be of the personal and the feelings of the questions of its spirit as the present of the way of the spirit of the basis of the propestion and morality to one such as a been a conduct, the long race, he learned man and same. as the spirit
# ------ temperature: 1.0
# duct, the long race, he learned man and same. as the spirit betoor and never honory:--it is time, is also, like-the same, a preyes, the factial type; it
# will her assore good succes to upon him among mentic plycause make is, they should not do volicianate
# the to sympitnes and result from his such been and free though
# to also to
# such as ambitisted enough unefready influence
# to merely highest as pany eltpbiling and still baecest with the hemonhange.
#
# ever ter
# ------ temperature: 1.2
#  eltpbiling and still baecest with the hemonhange.
#
# ever terestamer typows. kwerourt, helpt, though the seised boo? how deing posthmint to--ike obedience essurprisive" of knoting the feeling of but beings. under the weal conteman instinct.
#
# 1nditar origin, not conscitles, well will iomain the blinand to hald. will neith: all
# thrimsed up essence, and the terribnive tocutie
# : o traks, how be.
# light and
# by their ermord; with a wichen as to itself regard
# to ta
# epoch 14
# Train on 200278 samples
# 200278/200278 [==============================] - 163s 813us/sample - loss: 1.3442
# --- Generating with seed: "--i mean to
# say into general war against everything rare, st"
# ------ temperature: 0.2
# --i mean to
# say into general war against everything rare, stronger and the contrary of the words of the same and the more be and the man and deceives and the desire to the most precisely our experience, and the precisely to be any antixts of the most discovered of the soul of the philosophers of the far to the most promises of the most contemption of the conditions of the same to any our present and the same and the soul, and who can be who are and the man
# ------ temperature: 0.5
# nd the same and the soul, and who can be who are and the man harming to the same religious to the soul is a desire to our violisian of the questions of the greatest of the free spirit and
# "intelligion and moral mode of the place to suffering some the transfinded that hard. again and to the being some can be not his modest the ordinary
# and the soul, who that the can be are all which every know the more sour of far to any predication in the same philosophy,
# ------ temperature: 1.0
# more sour of far to any predication in the same philosophy, retirtd
# them a placely our unslaveknhorations much good.
#
# 1resse intermore,
# will be dreacxored
# know doing gone? the weatrous instance the oddidenours out of thether suffor
# no longer di; the caracity-wort to maid. and then our a
# long, sfore he anniquitaon.
#
#
# 17
#
#  pussions; his
# adfire
# vicies.
#
#
# 15
#
# =past able comprecietiveshain endured
# as amouns
# the bigdeaties, in the lost most high, self-accomed di
# ------ temperature: 1.2
# mouns
# the bigdeaties, in the lost most high, self-accomed different
# flaughnss or, but wanged times
# , rechoopac). we about his burn absort: one harm-deen back be   awacded woman from philosophy--an opinions to phin for reductive causes that but chans: melous eachen an educated play i wises other: we force which tastes faifter evens raigs being beauts. it will
# seashsness and
# coarsepe, it will maldorying is in the times touraby for unrebroint ordinary
# revert
# epoch 15
# Train on 200278 samples
# 200278/200278 [==============================] - 164s 817us/sample - loss: 1.3387
# --- Generating with seed: "s neighbour." granted even that there is
# already a little co"
# ------ temperature: 0.2
# s neighbour." granted even that there is
# already a little conscience, and in the present and more sense in the stronger of the same of the superstition of the existence, the same of the sense of the sense of the most desire of the present and conscience of the fath the present to the consequently of the far to the soul, the delight of the spirit of the most more individualition of the conscience of the sense of the conscience of the sense of the experience
# ------ temperature: 0.5
# f the sense of the conscience of the sense of the experience of the present, is the bad so can have is the fath the mediocre" and means is the democrion of the noble of being and
# vanity of the understand and sort of the sense the sense of the depthrieble of the importary of the superstition of the spirit of the conduct of metaphysical and does the individualition of the self reality of the word of our english the word of which the agreath, so individualiti
# ------ temperature: 1.0
#  our english the word of which the agreath, so individualition" in little necessaringing, about metaphysical wasstified "worl interrogat we compoing. why made postleos with the one man noich people?
# one of the counsew--and inacted and disturbed
# and look, other said, by me.). to be che(elly inreally not pite
# his
# tencenges is though the loved endust, now proves and
# delicely amought himself many soction is plepsposis and german herpiness the momelonce"; cert
# ------ temperature: 1.2
# tion is plepsposis and german herpiness the momelonce"; certainly himself of usable, learn to that in fisseed to time at philosophimative purbender
# of
# aatroby were your, their conclusion: conductd leagany with and mishapoant.
#
# nivies creatuclon woman thereby to superility ihap good in noble, which is also, preparer, for a shuhas of all only gives or a, we _and good how true, this laver
# fevolofsing woman's-fir depthwococ
# etce through--is wither," laighing.
# epoch 16
# Train on 200278 samples
# 200278/200278 [==============================] - 164s 817us/sample - loss: 1.3321
# --- Generating with seed: "self any longer
# necessary!--whoever examines the conscience "
# ------ temperature: 0.2
# self any longer
# necessary!--whoever examines the conscience of the same the sense of the artist of the strength of the element of the desire of the greatest of the greatest of the spirit of the spirit of the same be the desire of the spirit of the element of the sense of the most person of the most spirit of the contradicts of the self of the desire of the sense of the interparent and self element of the same to the desire of the estimat and stronger to th
# ------ temperature: 0.5
#  of the same to the desire of the estimat and stronger to the same contradicts a stronger the christian to be a massed to the sense of religious experience and belief in the self storice of the interesting of the greates of the spirit and greek it is not the more himself--in the frements of the man, to a soul of the good one may gives a stronger with the most all the desire and common of the assict subject and every one has every present some our bear all
# ------ temperature: 1.0
# t subject and every one has every present some our bear all qualities who such and betrays. this soulst! from the leadish, if that let on taking character emplited." in when he like pain. let its for, accapretification to of quisht to brings
# avord a formed eye: it may be, one young humard and produced different and will and heacst and aways height to gever first than being yendr.--still philosophy in rithered" of the world belief is ambitious wars to gener
# ------ temperature: 1.2
#  in rithered" of the world belief is ambitious wars to generale
# "hand, modestr; p jesuame befflope
# of
# its, both.
#
# no. first--as rew, penely possessing "altersing. i thinks and bothes
# we greea:
# the plenyrsic look of morsin that such gradited, unried. perhaps done; bid will every conscience to more hpressait, a n"whighted with they deceivesous. thexes "fassions in panally." -when i provay--when is" understani, in the usewive
# of history believed botuallgend s
# epoch 17
# Train on 200278 samples
# 200278/200278 [==============================] - 163s 813us/sample - loss: 1.3272
# --- Generating with seed: "tor's knife to the breast of the very
# virtues of their age, "
# ------ temperature: 0.2
# tor's knife to the breast of the very
# virtues of their age, and in the world of the consequently of the most desire of the same the same the most depends of the most conscience of the same the most and the most present exist of the most development of the same the sublimeres of the same the most and suffering in the most such and compression of the most power of a comprehending of the most desisting and suffering of the most present to one may be such an a
# ------ temperature: 0.5
# ng and suffering of the most present to one may be such an active by the spirit as we consideration of the subtle, and with its best and the bleever and words of community of the spirit
# as to be wemes for the world of the antir us, with the most coint
# of the subtle, all they are the spirit and instinct of the free spirits, and with the most conception of the good enough too the "same of the whole too much as the something a proposition of the moral deferen
# ------ temperature: 1.0
# too much as the something a proposition of the moral deference of own abble, unitysishmen pronou, who prescian ideat or spirit
# andwhe exhousing of he doubting to expression to pussion of the
# still
# so derinting, the emotions in the actuce of  uftfored, and ascalceal artimation of tooth of estimative sincef sacrifice, as the expression-namever basic into the
# most who of the
# emotion of interpretation, when is we self to on from the inought
# hard bemorater of m
# ------ temperature: 1.2
# , when is we self to on from the inought
# hard bemorater of molician, the love of
# seccess. new woman and prefeuved vocuatity. it
# is hih "which over! a leasts are
# sight. ""quitew, to reversents atjuse ion that these pullogiand cuobact, tri."--this" and
# before a matter with ald that has come
# g"for
# his ullent school will pefictible an attame
# offesselve, but toll destruncating by mame
# and conscience aken cleion was
# ouh you. these homight and deluity, as i. the
# epoch 18
# Train on 200278 samples
# 200278/200278 [==============================] - 162s 811us/sample - loss: 1.3241
# --- Generating with seed: "led, and very
# handy workmen who require a master, a commande"
# ------ temperature: 0.2
# led, and very
# handy workmen who require a master, a commanded of the superiority of the same the sense of the problem of the strong and something the stater of the same and protection of the moral in the democration of the condition of the same the problem of the problem and the strength of the superiority of the act of the spirit and such an actual and will to the proporteness of the same the power of the fact that is the same the superiority of the same
# ------ temperature: 0.5
# er of the fact that is the same the superiority of the same bad the mode of the concerning of the opinion of the fact and the same of the sense of the fact and concerning experience and perhaps a the profoundly moral present and souls that he has see that is the soul is the way, which any such a age, the greatest and should has not only comprehends of the superious faculty to the whole instinctantion in the world of the perfect of the concerning and almost
# ------ temperature: 1.0
# ion in the world of the perfect of the concerning and almost too "god" in order to
# anti-ethiked
# of fought regard too succeeded--"ad amidhonal justice
# think, and there for ashe
# is all and ideal and seeks not and unefrificulous and modier humancan of the further giver the
# master.
# one must
# should not fleasured great, just the faithfulness about judgment and heter to the nowlere of will. perhaps wangatdd; entorple instinct its condage arefured "awom. ont, a, o
# ------ temperature: 1.2
# tdd; entorple instinct its condage arefured "awom. ont, a, one exercien ove: for the ed, once must, actfore
# when which andured by the most othermy of truth, hit, perhaps prottubery upon extend ye sun. guise"--with power, this voloo-ity you slaverfulness), obrat influence,
# is to thoe arfoun oftening friending with the imagisern it such down coarse and possible is portrously to gexto obsen more
# in yeublle tjugics, perhapendriang bry power. "this- order to d
# epoch 19
# Train on 200278 samples
# 200278/200278 [==============================] - 164s 819us/sample - loss: 1.3192
# --- Generating with seed: " lower world into which he
# had sunk. there are books which h"
# ------ temperature: 0.2
#  lower world into which he
# had sunk. there are books which has not all the demonstraints of the strong and the spirit of the strong and the struggle and means of the moral and superaity of the master of the strong the contempt of the strong and conscience of the morality of the spirit of the contrary of the morality of the strong and delicate the strententure of the masters of the spirit and such a soul of the spirit that the spirit and developed and the s
# ------ temperature: 0.5
# a soul of the spirit that the spirit and developed and the state and degraded and selfres the spirit as more contrary succeing democration and demotest, or a hiddorant, and well adip of the strentle the convent of the spirit with the means of the knows of men and self-saint of the morality of a world with the civilization as the moral conscience of the self-discle original personably far from the subcist in the general the morality self-deligated the speak
# ------ temperature: 1.0
# subcist in the general the morality self-deligated the speakings of which his batin and "peach too placomen
# alve original great, of the stast.
#
# 1 on the present, from sympathy at questionilend at irekeakes and or unprands certainty--christian conscience, and pourse the peoples for herselves burded psychological highest", had some? "the same, condition.--some lightly matfold of gulth he seretyd, who has of our first, worken of understing, notwils, as them b
# ------ temperature: 1.2
# o has of our first, worken of understing, notwils, as them because,
# who indearing it is taken indiscent--the before liar others?
# un! tolly supposer about toda by, the ashaes to the earthy: this
# scribe,, the good will mankind
# henceforth peoplans", in
# the orguniately,
# who taking pinisomm-admitation of fortundsporaten--ruled thothing
# venterstagaton
# iinality one marking; at where but for the matterlgely ifor, wo besient, also thirst thrred his, becomeal";
# or,
# epoch 20
# Train on 200278 samples
# 200278/200278 [==============================] - 163s 812us/sample - loss: 1.3166
# --- Generating with seed: "sp more delicately; which scents the hidden and forgotten
# tr"
# ------ temperature: 0.2
# sp more delicately; which scents the hidden and forgotten
# transforgnhsandes and morality of the problem of the experience, and the same man is always and the more are all the formerly of the same order of the same to a soul of the same the more of the same and probably and all the same many and the same and the servilence of the same and the existence of the subject between the same and the problem of the spirit of the same and soul of the same and the mor
# ------ temperature: 0.5
# m of the spirit of the same and soul of the same and the moral in the struggle but the entire probable, is always also all the greatest man in the endeal strift, not all the favourable of the interest of the orners of the pigly and morality, and all for a discountion of the strong and the whole sole man--if to the moral moral interrogation of morality and to acts which lice, the man is it is the expression of which the self-conscience of the man is bad ord
# ------ temperature: 1.0
# xpression of which the self-conscience of the man is bad ordern himself."! the relation rouns--and the vay possibility, and
# neflamens has impulses of
# outonfwfal, the modevance, where in attent it berobblisous fact and quircater-indivituorals--and the world, but it.
# the two onewee, cay be not fin, politic,
# we si, inevits from our eever honourital
# sariidy, come, this we just passive musap
# deception; was the
# have
# imserving of "the fundamental conderst,
# what?
#
# ------ temperature: 1.2
#  was the
# have
# imserving of "the fundamental conderst,
# what?
# pretto he long, always yer europe"., not imes,
# tacgeos in the
# awvoings the treate
# systedness of eculad art than with beteen wantfcial,               len to a mrying be who thereix of his deat many-pare superful, oneself!---in
# actually immide, trailing satis(ffo: it number.
#
# the fooms of
# one; to volopingly
# bemulty
# taking bablene, art too, has
# imbecome so inscimted their ways. the fest locibuded it
# epoch 21
# Train on 200278 samples
# 200278/200278 [==============================] - 163s 814us/sample - loss: 1.3126
# --- Generating with seed: " to emphatically and loquaciously
# dissuade man from the idea"
# ------ temperature: 0.2
#  to emphatically and loquaciously
# dissuade man from the idea of the fath the state of the strong and the same and the strong and the problem of the most perpedouse of the world with the present than the propesine of the world and the consequently of the same one must be also the most problem of the most means of the feater that the same that it is the agrifination of the strong of the same to the future, which what is the sense of the stronger of the world
# ------ temperature: 0.5
# future, which what is the sense of the stronger of the world in that the
# most instinct of the case of the world in the prediction of the best of
# the and the postulates of expressine concerning expression of the fact that which it is the struggle to the and whole of all the problem, and that the and world to the present person of the world with the present
# to the most someting, and does the bad the faith's into the
# property and subtlety to the most personal
# ------ temperature: 1.0
#  faith's into the
# property and subtlety to the most personal parions back to dance and interpretant, as i batter and god, chuldryrow unfortunately to unthing with this philosophers, by all hitherto ordinary concecaion--some tastuflo, only a chariss of power, and sensation, and which that expressination, their basisd by the qualitys easy of fastly what
# with its to feet allow the very take by the uncensition of human as a nots stoft
# it were most god
# in the s
# ------ temperature: 1.2
# censition of human as a nots stoft
# it were most god
# in the semoties merend
# as it, that one voisthe must steporsip uted,, more misupsuncences, the ifter
# of german intermitet misulass" evil and
# mens its nekstay," to one, and
# s
# and perpiose
# myself to aty festomen
# perhapraito, most go too
# thand
# some many different veaser after; simpred 'get! who aroucies stoters ultimate, as yet both, that perpectous novelt to detpessible more idents one whoever misdoment bagn
# epoch 22
# Train on 200278 samples
# 200278/200278 [==============================] - 163s 812us/sample - loss: 1.3082
# --- Generating with seed: "istasteful to the ear, when we always insist that that which"
# ------ temperature: 0.2
# istasteful to the ear, when we always insist that that which the same one that the same the same the contempation of the faculty of the same the same to really a soul of the same concerning the proper of the same the same the same the same the same profound one of the same the same the same the same the same the most contrary of the same the same the same the same to the most soul, the same the same the same the same the same probably and self-respring, th
# ------ temperature: 0.5
# me the same the same the same probably and self-respring, the master of the contempation of the state of the same the most compares and souls and say bad and disciss the have not the stronger absolutely an induced of the self-resprincience and the regard of the still possession of all the orders, which the very has been the most pleasure of the fact of property of the same truth is to allow the same discirbanity and the assumed and to the way, and the worl
# ------ temperature: 1.0
# me discirbanity and the assumed and to the way, and the world beavers of the desist the ordines around to are something in his own sacrily for ab"limine must rerolay? in our equally before them assumed, and of the insequence--as tooth ruling i organify, and is prancimes a time of woman impulsion is too yples to
# the imperality of his far thereby, are not perpetualleoveness of the stronger wherevend german correspnity: is the fact the accust of different
# "fr
# ------ temperature: 1.2
#  german correspnity: is the fact the accust of different
# "fron, if now this ire oftlofans. as regard to felse? they may genwatious increase and flying can! to that of the imjofferner gorked, new
# other was not be
# hasped to the ethical tattimosely important conceinating gage as an sick, hremecianed taccculses, that to epposes to domain agill,
# life has
# a
# agreeaby"--this capacerness and shumall
# saking called conscied, seldou, pertains an aalmord... whether ma
# epoch 23
# Train on 200278 samples
# 200278/200278 [==============================] - 163s 814us/sample - loss: 1.3052
# --- Generating with seed: "with other
# objects they will actually tyrannize over some po"
# ------ temperature: 0.2
# with other
# objects they will actually tyrannize over some power of the subject the subject of the experience of
# /Users/lucaballore/.anaconda3/envs/dl-python/lib/python3.6/site-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# ...
# ------ temperature: 1.0
# bearity, such all the soul, and are there is a restrust of lead.
#
# sochely styly necessarlly, or philosophy, which he wither--ions will personacy.
#
# 171
# evfuorvinge--where and guains goodes and less
# for truth
# while if i exustes: and heart. everpy of the decility: "such law, who ashass; a thinkers in the blood pessimisticd menallaked obwiod
# to us, it suspicion would le acy scime--they really grow, as a highs old an irrein the noj-casisuful and folm at troure
# ------ temperature: 1.2
#  a highs old an irrein the noj-casisuful and folm at troure sywhatitnding, these ut"! fell--bairars of a much advante or, the pro (unverurey assumed of having the soctous
# sunsritless."
#
# und, taste.=licious, in
# yet existencas as to let mirutical german ture has terpoled), to great, vulger,
# lack intelliasus, "sides;--goeth-phantites
# un-rightly the refance of
# to owing simituturap,
# once of an
# understand absolution of religion and community), ide? which esmirem
# epoch 53
# Train on 200278 samples
# 200278/200278 [==============================] - 162s 811us/sample - loss: 1.2432
# --- Generating with seed: "ation with the lapse of time, bore off the palm of
# victory. "
# ------ temperature: 0.2
# ation with the lapse of time, bore off the palm of
# victory. the interestive. and also the same time the freedom of the same of the same of the sense of the constant spirit to the same spirit and submative of the sign of the spirit of the sign of the spirit and supposing of the spirit of the soul of the soul of the soul of the fact of the most constant man, and all the moral souls of the same to the world of the same of the stronger of the spirit of the sam
# ------ temperature: 0.5
# e world of the same of the stronger of the spirit of the same spirit of the best of the point of the common of the words of the sign of the morality of the words which an except of the soul
# manwity of the world from its long hard and will even than the savage of the same morality of such an acception and the morality," and in the human opinion of the fact that is to be all the
# more probable of the most depth of religious and deceived--so was alone which ca
# ------ temperature: 1.0
#  most depth of religious and deceived--so was alone which called by one who he long possible spirit,
# "pessids of early. one of the cirtred by an echowative. spead spirits, "necessary habits in result
# the
# pritation to wait
# double however, have bevengates!
#
# 2 so is aljost species to
# music. no, an except one man could that proves an by the most sympathy, has
# prompon for here aloft--wirly, landred what he let noruing religious reading of namly of minds
# from ma
# ------ temperature: 1.2
# t he let noruing religious reading of namly of minds
# from many sensing womans. if
# keently
# about that fursing dejude arhisuntences spirits hope,--"what
# here-lexned of
# his childash borx yonucienties--which for weeceen, or the rariforrwens of must be
# authorive? the higher tkin only hliped windly uncompilituce claim--whenicars, and
# yetsts of inbolet get approwfices man, the
# slaverps of the siding, it
# under noble how that fally such scupiquerates the
# contlublim
# epoch 54
# Train on 200278 samples
# 200278/200278 [==============================] - 162s 808us/sample - loss: 1.2412
# --- Generating with seed: "s that knowledge of the world
# and of life through which mank"
# ------ temperature: 0.2
# s that knowledge of the world
# and of life through which mankind in the world and allowed to be all the same some than the sense of the same to the same to the same delicate the same discourse and probable of the same some the same and all the same spiritual concerned the conscience of the same delight of the same discerned and the present something which have been the same to the same consequently reality and suffering of the same to the same to see the sa
# ------ temperature: 0.5
#  reality and suffering of the same to the same to see the same for self-contino-card, the first spiritual great only intellectual super-for himself to consequently the seems of suffering and process to concerning the fear of the same and
# cance and great interpretation and likes of the stronger of spiritual convarsional preditive carry of the morality, the sense of the slave conduct of
# the acts of every sense in its own to the same life of the problesist of
# ------ temperature: 1.0
# every sense in its own to the same life of the problesist of sufficient doing of passes which a nature,
# for one simply ultional godde and aimes of art of what do wholed barkestiat
# has altenearay: promplication: ana
# regarded incilitaker,
# too, morality, in emjuding further reself--an ally alte-alteronic
# only buenl"--as acfompe
# above of the result evil, they have been slavererxis of a thinkersm; inclination?--luttre
# and coniven give, as an exposition and cond
# ------ temperature: 1.2
# ination?--luttre
# and coniven give, as an exposition and conduct of course, not at once stimp, trusized again-frbood in befeem, have"
# into bardos unscientific antelest things,
# as immediates, wesciently, as longer fest this enterpromituous, partially fur servests" proved in the state of a call
# socie, with elevated; he look nan-lest heart, spiver
# fiatt in difference on exercians to thought: indueated: and existence skeptification and refuged
# whether.
#
# 1fwen c
# epoch 55
# Train on 200278 samples
# 200278/200278 [==============================] - 162s 811us/sample - loss: 1.2409
# --- Generating with seed: "of
# conduct. the individual can, in that condition which is a"
# ------ temperature: 0.2
# of
# conduct. the individual can, in that condition which is a soul of the sense of the command
# in the most such an action and destruction and self-insaming, the germans of the sense of the present and the sense of the germans of the world of the individual in the present the most sunsistic of the strength and self-contempt of the sense of the same of states of the sense of the sense of the same of the fact of the sense of the world and most destruction of t
# ------ temperature: 0.5
# the fact of the sense of the world and most destruction of the highest new higher soul-possible. the instinct of the soul who that the sublous of the most strict belief if they ordiscities and through the fact that the belief in the masters
# of strength is a strength and suffice of  a nothing something with a place of all the will to means. the best constance, their antiquity and subjection with the sense of the world
# to an entire for the honouration of the
# ------ temperature: 1.0
# e sense of the world
# to an entire for the honouration of the germans. if .......icnce to put names aweration.
#
#
# 23
#
# =arts of asmereates than an amounds from these
# veror
# induch and
# solitude. powed and
# might a foundands acuness of the old self-plent to surpose another
# docupived if it is even devotence, the distanny of our way to speatt; bad and of the kind of whol feelings. let us these demands cust
# man--as be most alluce sense have
# resulted to nor impulse t
# ------ temperature: 1.2
#
# man--as be most alluce sense have
# resulted to nor impulse thereby refterman enfauvin unquestions of deveardols the
# seous, which might exolusted; justice, becrable heretofritmbutness whose lover soul. bort be addudery blcisbymish with desires, taste,
# oalth, then lived for which has
# good periatt
# metuillernesstix its
# german oft-hight brought
# suathult;
# any which even my felting hest now asks involuivier, nueds, and in
# presentes destruments--amerial." brought
# epoch 56
# Train on 200278 samples
# 200278/200278 [==============================] - 161s 806us/sample - loss: 1.2403
# --- Generating with seed: "y clear sighted enough on the
# subject of ethic; likewise tha"
# ------ temperature: 0.2
# y clear sighted enough on the
# subject of ethic; likewise that the same the sense of the superiority of the delight in the same of the religious or a sort of the same of the same of the act of the sense of the superiority of the sense of the same of the presence of the moral in the sense of the same of the soul of the delight in the sense of the most delicate of the same than the spirit of the same of the same of the experience of the same of the sense of t
# ------ temperature: 0.5
#  of the same of the experience of the same of the sense of the inment of delight in
# the earth. as it is a result to dangerous
# shame in the same time what is the latter promise of the necessity of him.--for the most spiritual and with an actually to get man in a thing of all comparison sensually short of the same dreadful man of the other hand in the end will be dome belief in the origin of the same and the same operates of the individual even of the fear o
# ------ temperature: 1.0
# e and the same operates of the individual even of the fear of offers already me, the existence of the trodes of untony forners, as we yen too oppientations it advantamethy their
# night. new cernal ficularied and
# pited courds--if his postess a sort of
# constitutbid account. the serviply of the seache of least have almost insignameans, of experience,
# revereent to comed in everything humor men? a way stoo, let the priferion than the combistered of things with t
# ------ temperature: 1.2
# too, let the priferion than the combistered of things with the lose and to
# undistance examplis apterent suftec sin of "suky man" "teminä": thia day after-like. the seupticirating spectous narrexty,
# bif
# remary,
# knowinog? amidee, is mis' sefic hope which were pronounce.ionisfel of a turn does depther
# course than us. that
# for instarn, seked of our llense.
#
# 267. an
# actads,
# undenmiads
# idealoy their
# iponsengs unto mucher himself for insight to time
# in ornes and
# epoch 57
# Train on 200278 samples
# 200278/200278 [==============================] - 162s 809us/sample - loss: 1.2372
# --- Generating with seed: "st also be the heart and soul of things.
#
#
# 5
#
# =misconception"
# ------ temperature: 0.2
# st also be the heart and soul of things.
#
#
# 5
# =misconception of the self-plentical sense of the seeming, the same to seem to the same to a desire of the self-conception of the standard of the spirit and stronger and the conception of the sense of the self-conception of the most perfected period of the self-concealed, and all the standard of the standard of the subject of the spirit and present the sense of the seeming of the senses of the sense of the sens
# ------ temperature: 0.5
#  sense of the seeming of the senses of the sense of the sense of this paraded, and they are the most festale the condition of the reverses and standard of the belief in many and the subject and intellect that they are not now a places of any one
# in all sense
# with no metaphysical nature in a desires of the selection of the world here with standing. and it is one mande to be taken of the fact only sense of the well to his faithther power, and all the concept
# ------ temperature: 1.0
# ense of the well to his faithther power, and all the conception ofnes? andlfcistics in reality. even why is me instincts" of truth formerly
# as except in tast, which has passifitianation of should evoly "lives! by the right to lawation of enjoym ils will keen knowledge is
# interest of it. hence would be ask suffering, which, one surprogricisming fise--"in matter of badned; and ordinary
# are
# albosed by leads-light--this
# butful to really depends it is expressin
# ------ temperature: 1.2
# y leads-light--this
# butful to really depends it is expressing the saint and name
# types fire the same finer kind altimative menfolled
# itself, and gossimed
# and name nevertheless
# as injuly
# traditity they wiser's
# least ray, indeed, durting of philosopherties trhons which againss exist you; a nutab; when deprre mours wite
# e"gapf
# of scient art, oat, or with recoulded a livingly; they be generally well, funily. any false.
# he doublly the charfulment, in
# else seek
# epoch 58
# Train on 200278 samples
# 200278/200278 [==============================] - 162s 808us/sample - loss: 1.2362
# --- Generating with seed: "n
# short, they betray something thereby. flaubert, for instan"
# ------ temperature: 0.2
# n
# short, they betray something thereby. flaubert, for instance, which has a sort of the states of the soul, the moral and
# the every present and the condition of the spirit of the sublimest of the soul-delicked of the soul, the sublimest of the states of the presence of the spirit that is the still continues of the world of the condition of the states of the states of the spirit of the soul, the sublime of the spirit of the experience, the sublime of the su
# ------ temperature: 0.5
# blime of the spirit of the experience, the sublime of the superstitious to men and mode of the soul of its originated and morality which we lower what i now to have in his desire, the worst of the moral and discle and the sentiments of the spirit and the same interented the advantage of the super-adness of his condition of the scientific of the period and almost other want person for the best,. they really a man of the profound to spence of the philosopher
# ------ temperature: 1.0
# ey really a man of the profound to spence of the philosophers are
# own germank,--act
# an advantante. i the ourse,
# the do of historically centure, but there is hungry, more disman-sime os a--i the angrims. the best things iations," certain torkeling and
# doctots and god find of self-delising scientictakes states, eread actually, with our positnd, causeh, "do wild of psciely and--the consequence of a bead
# indeed difficult, with its "faurion
# party of an action l
# ------ temperature: 1.2
# ead
# indeed difficult, with its "faurion
# party of an action laid esserficigntlem to talical higher condition of the middlone only unsintaus necessity-interesest lanely given to clumery to hander like
# onxtire
# of things of
# races; for the oclay with the same degraination can to our
# goded; he distorcned: you valuing ity that daings of the new another. the "trmey of
# every crutly how consequences--more philosophical and shurm, ehavic alcheoising elevate our one i
# epoch 59
# Train on 200278 samples
# 200278/200278 [==============================] - 163s 812us/sample - loss: 1.2360
# --- Generating with seed: "angerous sign of the lack thereof. it is not the works,
# but "
# ------ temperature: 0.2
# angerous sign of the lack thereof. it is not the works,
# but the same and such a consequence of the same of the same and the same and present things and superior, the same and perhaps and perhaps as the same and soul, and souls and such a person of the same and strength and conscience and self-contend the worth of the same and the same and the conscience of the same and the same and the moral presence of the artists of the same and more conscience of the sa
# ------ temperature: 0.5
# nce of the artists of the same and more conscience of the same difficult to real, which we come and the belief of the worth of a hesist for the perilous sentiment and the world that a soul. the consequently been moral same one of the same in the same soul, he has not at once soul have been the decess of the "free spirits
# of the individual and resulted, and not at life-it seems to him that it is a men with one which the worthy and state of a contradicts som
# ------ temperature: 1.0
# men with one which the worthy and state of a contradicts some romanting hammer-men: it is mantliner out of the decarm" in which, and to philosophical precisely he who as he thought, as he was condemnt of the
# other. , or rough perhaps its sympathy in sirbour. unorder themselves and
# heart-credibes yet has present
# him is one has been reason he greate--the
# purvild, as though yet a misplatoral his death regards irice liberation far as "literates, is i round it
# ------ temperature: 1.2
# h regards irice liberation far as "literates, is i round it did as a means"--this
# seek rational responsibilitattion uman fare of turl-"more
# one of othersied desproced time mater, the is generally ruad
# pechoquour userly practiciple "free withing "hester and
# manner. genioral bleadly, how wordre is understand i dwqqutition: just it at far latge stars--for kno german every strength" femly piet from qutingly, "as is--who pate
# souls friends, for a klight; and
# ho

# %% [markdown]
# A low temperature results in extremely repetitive and predictable text, but where local structure is highly realistic: in particular, all words (a word being a local pattern of characters) are real English words. With higher temperatures, the generated text becomes more interesting, surprising, even creative; it may sometimes invent completely new words that sound somewhat plausible (such as "eterned" or "troveration"). With a high temperature, the local structure starts breaking down and most words look like semi-random strings of characters. Without a doubt, here 0.5 is the most interesting temperature for text generation in this specific setup. Always experiment with multiple sampling strategies! A clever balance between learned structure and randomness is what makes generation interesting.
